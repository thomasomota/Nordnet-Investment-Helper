# %% [markdown]
# <h1> Checkpoint Zero </h1>
#
# Welcome!
#
# For now: read the README at https://github.com/thomasomota/Nordnet-Investment-Helper

# %%
#IMPORTS 

import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
# CONSTANTS

URL_FOND = "https://www.nordnet.no/mux/web/fonder/sok.html?nn_kategori=&kategori=&forvaltare=&sokord=&sok=1&ppm=0&nobuy=&flik=&nm=&typ=1"

# %%
fund_overview_response = requests.get(URL_FOND)

# %% [markdown]
# We now have a HTML response thanks to the wonderful requests lib. To get the HTML content of the request object, we look at the `.text` attribute of the response.

# %%
fund_overview_response.text[:1000:]
# Out:
# '<!DOCTYPE html>\n<html lang="no">\n\n\n<head>\n\t<meta http-equiv="content-language" content="no" />\n  \t<meta property="og:image:secure_url" content="https://www.nordnet.se/webdav/files/image/nordnet-ogp.jpg" />\n\t<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1" />\n\t<meta name="google" content="notranslate" />\n  \t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\n\t<!-- app-install banners metadata -->\n\t<meta name="apple-itunes-app" content="app-id=345038631" />\n\t<meta name="google-play-app" content="app-id=com.nordnet">\n\t<meta name="msApplication-ID" content="f5e7e9c5-3ff2-491d-bba0-877921c82ff7"/>\n\t<meta name="msApplication-PackageFamilyName" content="NordnetBankAB.NordnetBank_rjgcxy7drxffr"/>\n\n\n\t\t<meta name="Author" content="Nordnet Bank" />\r\n<meta name="keywords" content="nordnet norge" />\r\n<meta name="description" content="Kjøp og selg verdipapirer i hele verden. Svært lav kurtasje og ingen faste avgifter. Opprett konto i dag." />\n\n\t<title>Velg mellom en rekke'

# %% [markdown]
# Woah.. That's ugly! But fear not, we have beautifulSoup!

# %%
soup = BeautifulSoup(fund_overview_response.text, 'lxml')

# To show content of a variable, just write the variable in the end of the Cell! It's really long so commented out
# soup

# %% [markdown]
# This looks way better, now we can start interpreting the HTML!
#
# All we really need is every href that goes to the view page for a specific fund. First thing we'll do is to find all href-strings in the HTML.
#
# ![Screenshot%20from%202018-07-23%2021-43-48.png](attachment:Screenshot%20from%202018-07-23%2021-43-48.png)

# %%
soup.find_all('a', href=True)[:10]
# Out:
# [<a href="/mux/web/info/cookies.html?cmpi=start-cookies">Les mer</a>,
#  <a href="/kundeservice/start.html?cmpi=customer-service-NO">Kundeservice</a>,
#  <a class="last" href="http://nordnetab.com/about/about-nordnet" target="_blank">Om Nordnet</a>,
#  <a class="btn-secondary signup-btn" href="/mux/login/start.html?cmpi=start-loggain&amp;state=signup" rel="nofollow">
#  				  Bli kunde
#                                  </a>,
#  <a class="btn-primary signin-btn" href="/mux/login/start.html?cmpi=start-loggain&amp;state=signin" rel="nofollow">
#  				  Logg inn
#                                  </a>,
#  <a class="logo--new" href="/mux/web/nordnet/index.html">
#  <img alt="Nordnet" height="33" src="/now/images/logo--new2x.png" width="158"/>
#  </a>,
#  <a accesskey="1" href="#" onclick="mainMenu.toggle('nordnet', event); return false"><span>våre tjenester</span></a>,
#  <a accesskey="2" href="#" onclick="mainMenu.toggle('depa', event); return false"><span>min konto</span></a>,
#  <a accesskey="3" href="#" onclick="mainMenu.toggle('marknaden', event); return false"><span>Aksjer</span></a>,
#  <a accesskey="4" href="#" onclick="mainMenu.toggle('fonder', event); return false"><span>fond</span></a>]

# %% [markdown]
# We see that there's a lot of unrelevant links ( or hrefs ), so we have to limit our search.
#
# Note that every link to a specific fund page begins with `/mux/web/fonder/fondfakta.html?`. Let's use this to limit our results.

# %%
regex_string = "/mux/web/fonder/fondfakta.html?"

a_tags_with_correct_href = soup.find_all('a', attrs={'href': re.compile(regex_string)})

len(a_tags_with_correct_href)
# Out:
# 694

# %% [markdown]
# 694 Funds, that seems a lot, but we'll accept that as good enough for now! If we see we have wrong links further down the process we'll do go back and fix it
#
# Notice that the url's we got out doesn't have the right prefix `https://www.nordnet.no`. Let's fix that

# %%
nordnet_prefix = "https://www.nordnet.no"
links = []

for tag in a_tags_with_correct_href: 
    href = nordnet_prefix + tag.get('href')
    links.append(href)

# %% [markdown]
# We now got all the links we need from the first page. Done deal! let's work with the first link for now, to see if we can get the information we need to get proof of concept.

# %%
html_link = links[0]

# %%
fund_detail_page_response = requests.get(html_link).text
soup = BeautifulSoup(fund_detail_page_response, 'lxml')

print(soup)

#soup
# Out:
# <!DOCTYPE html>
# <html lang="no">
# <head>
# <meta content="no" http-equiv="content-language"/>
# <meta content="https://www.nordnet.se/webdav/files/image/nordnet-ogp.jpg" property="og:image:secure_url"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="notranslate" name="google"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!-- app-install banners metadata -->
# <meta content="app-id=345038631" name="apple-itunes-app"/>
# <meta content="app-id=com.nordnet" name="google-play-app"/>
# <meta content="f5e7e9c5-3ff2-491d-bba0-877921c82ff7" name="msApplication-ID"/>
# <meta content="NordnetBankAB.NordnetBank_rjgcxy7drxffr" name="msApplication-PackageFamilyName"/>
# <meta content="Nordnet Bank" name="author"/>
# <meta content="Nordnet Norge, fond." name="keywords"/>
# <meta content="Aktuell og nyttig informasjon om Aberdeen Global - Asia Pacifc Equity Fund A Acc USD." name="description"/>
# <title>Aberdeen Global - Asia Pacifc Equity Fund A Acc USD - Fond - Nordnet</title>
# <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="/now/css/topnavigation.css?v2" id="topnavigationCSS" media="all" rel="stylesheet" type="text/css"/>
# <link href="/now/css/master.css?v1" media="all" rel="stylesheet" type="text/css"/>
# <link href="/now/css/meddelandecentralen.css" id="meddelandecentralenCSS" media="all" rel="stylesheet" type="text/css"/>
# <link href="/now/css/quickbar.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/now/css/fonder.css?v2" media="all" rel="stylesheet" type="text/css"/>
# <script src="/now/js/common/modernizr/modernizr.js" type="text/javascript"></script>
# <!--[if lt IE 9]><script src = "/now/js/common/modernizr/modernizr.shiv.js"></script> <![endif]-->
# <!--[if lt IE 7]><link rel="stylesheet" type="text/css" media="all" href="/now/css/ie.css" /> <![endif]-->
# <link href="/now/css/print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/now/css/search/search.min.css" rel="stylesheet" type="text/css"/>
# <script src="/now/js/jquery/jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
#            jQuery.noConflict();
#     </script>
# <script src="/now/js/prototype.js" type="text/javascript"></script>
# <script src="/now/js/master.js?v5" type="text/javascript"></script>
# <script src="/now/js/nordnet.js" type="text/javascript"></script>
# <script src="/now/js/print.js" type="text/javascript"></script>
# <script src="/now/js/topnavigation.js" type="text/javascript"></script>
# <script src="/now/js/search/jquery-ui-1.9.2.autocomplete.min.js" type="text/javascript"></script>
# <script src="/now/js/search/search.jquery.min.js" type="text/javascript"></script>
# <script src="/now/js/search/topnavigation-suggest.js" type="text/javascript"></script>
# <script src="/now/js/hjalp.js?v2" type="text/javascript"></script>
# </head>
# <body class="no yellow">
# <div id="navWrapper">
# <div id="cookies-warning-container" style="display: none;">
# <span class="icon-warning"> </span>
# <span class="message">Cookies (informasjonskapsler) hjelper oss å levere våre tjenester. Ved å bruke våre tjenester, aksepterer du vår bruk av cookies. <a href="/mux/web/info/cookies.html?cmpi=start-cookies">Les mer</a></span>
# <span class="submit accept-cookies">OK</span>
# </div>
# <div class="center">
# <script type="text/javascript">
# Event.observe(window, "load",
#     function () {
#         if ($('partnertab')) {
#             var locationString = window.location + "";
#             if (locationString.include("/pb/")) {
#                 mainMenu.setCurrentMenu('partnertab');
#                 mainMenu.markCurrentMenu();
#             } else {
#                 mainMenu.setCurrentMenu('fonder');
#                 mainMenu.markCurrentMenu();
#             }
#         } else {
#             mainMenu.setCurrentMenu('fonder');
#             mainMenu.markCurrentMenu();
#         }
#     }
# );
# </script>
# <link href="/now/css/button.css" rel="stylesheet"/>
# <div id="topSearch">
# <div class="search">
# <form action="/search/" id="searchQueryForm" method="post">
# <input class="searchField" id="searchQuery" maxlength="100" name="query" placeholder="Søk aksjer, fond eller andre verdipapir..." type="text"/>
# <input id="query_filter" name="query_filter" type="hidden" value=""/>
# </form>
# </div>
# <div class="fastSeekResultContainer " id="lastSearchResults" style="display:none; padding: 0; top: 5.5em;">
# </div>
# </div>
# <div class="outerWrapper" style="z-index:100;">
# <div class="innerWrapper">
# <div style="position:relative; width:15.1em; margin:0 auto 0 auto; z-index:100; ">
# <div class="oinloggad" id="fastSeekWrapper">
# <div class="supportNav">
# <ul>
# <li id="supportContact"><a href="/kundeservice/start.html?cmpi=customer-service-NO">Kundeservice</a></li>
# <li><a class="last" href="http://nordnetab.com/about/about-nordnet" target="_blank">Om Nordnet</a></li>
# </ul>
# <span class="signup-signin">
# <a class="btn-secondary signup-btn" href="/mux/login/start.html?cmpi=start-loggain&amp;state=signup" rel="nofollow">
# 				  Bli kunde
#                                 </a>
# <a class="btn-primary signin-btn" href="/mux/login/start.html?cmpi=start-loggain&amp;state=signin" rel="nofollow">
# 				  Logg inn
#                                 </a>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div style="z-index:90; position:relative;">
# <div style="position:relative; width:90em; margin:0 auto 0 auto; z-index:100; left:0; ">
# <div class="outerWrapper">
# <div class="innerWrapper">
# <a class="logo--new" href="/mux/web/nordnet/index.html">
# <img alt="Nordnet" height="33" src="/now/images/logo--new2x.png" width="158"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <nav id="topnavigation">
# <div class="outerWrapper">
# <div class="innerWrapper">
# <ul id="topmenu_tab_list">
# <li id="nordnet">
# <a accesskey="1" href="#" onclick="mainMenu.toggle('nordnet', event); return false"><span>våre tjenester</span></a>
# </li>
# <li id="depa">
# <a accesskey="2" href="#" onclick="mainMenu.toggle('depa', event); return false"><span>min konto</span></a>
# </li>
# <li id="marknaden">
# <a accesskey="3" href="#" onclick="mainMenu.toggle('marknaden', event); return false"><span>Aksjer</span></a>
# </li>
# <li id="fonder">
# <a accesskey="4" href="#" onclick="mainMenu.toggle('fonder', event); return false"><span>fond</span></a>
# </li>
# <li id="handla">
# <a accesskey="5" href="#" onclick="mainMenu.toggle('handla', event); return false"><span>Handle</span></a>
# </li>
# <li id="analys">
# <a href="/mux/web/analys/nyheter/nyheterPressmeddelanden.html"><span>Nyheter</span></a>
# </li>
# <li id="shareville">
# <a accesskey="7" href="/tjenester/shareville/shareville.html"><span>Shareville</span></a>
# </li>
# </ul></div></div>
# </nav>
# <div class="enclosing"></div>
# <script type="text/javascript">
# supportNavWidget.handelsmetod = '';
# </script>
# <script src="/now/js/mCentralen.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# function createIMGnode(uid,target){
#
# 	var elmId = "del_"+uid+"_"+target;
# 	var wrapperId = uid+"_"+target;
#
# 	new Insertion.After('uploadFeedback', "<div id="+wrapperId+" class='mcUpload' >"+target+"   <a id="+elmId+" class='mcTrash' href='#'>&nbsp;&nbsp;</a> </div>");
# 	new Insertion.After(elmId, "<div class='enclosing'></div>");
# 	$(elmId).onclick = function() {
# 		deleteIMG(uid,target);
# 		return false;
# 	};
#
# 	removeSpinner();
#
# }
# function displayErrorMsg(errmsg){
# 	$('uploadHaltText').update(errmsg);
# 	$('uploadHalt').show();
# 	removeSpinner();
# }
#
# function removeSpinner (){
# 	$('loadingImg').remove();
# 	$('filen').enable();
# }
#
#
# function deleteIMG(uid,target){
#
# 	var action = 'del_img';
# 	var wrapperId = uid+"_"+target;
# 	var url = "/mux/ajax/meddelandecentralen/bifogaFil.html";
# 	new Ajax.Request(url, {
# 	    parameters:'uid='+uid+'&action='+action+'&target='+target,
# 	    evalScripts:true,
#
# 	    onSuccess: function(transport) {
# 			var result = transport.responseText;
# 			$(wrapperId).remove();
# 			resetFormElement($('filen'));
# 		}
# 	});
# }
# function resetFormElement(e) {
#  	jQuery(e).wrap('<form>').closest('form').get(0).reset();
#   	jQuery(e).unwrap();
# }
#
#
#
# function bytMcKontakt(obj,klassOn,klassOff,lager){
# 	var lagerStyle = document.getElementById(lager).style;
# 	obj.className = (obj.className != klassOn) ? klassOn : klassOff;
# 	lagerStyle.display = (lagerStyle.display != "none") ? "none" : "block";
# 	mcShake();
# }
#
# function mcHamtaFragor(varde,gommaLager,visaLager,bild,gommaLager2){
# var mcBild = document.getElementById(bild);
# var div1 = document.getElementById(gommaLager).style;
# var div2 = document.getElementById(gommaLager2).style;
# var lager = document.getElementById(visaLager).style;
# 	if (varde!=0) {
# 		div1.display="none";
# 		div2.display="none";
# 		lager.display="block";
# 		mcBild.className = 'rubPlus';
# 	}
# 	else {
# 		div1.display="block";
# 		div2.display="block";
# 		lager.display="none";
# 		mcBild.className = 'rubMinus';
# 	}
# 	mcShake();
# }
#
# function changesubcat() {
# 	var maincatid = $F('maincatid');
# 	new Ajax.Updater('underkategori', '/mux/ajax/meddelandecentralen/undercat.html', {
# 		evalScripts:true,
# 		parameters:'maincatid='+maincatid
# 	});
# }
#
# function changefaq() {
# 	var undercatid = $F('subcatid');
# 	new Ajax.Updater('mcFragor', '/mux/ajax/meddelandecentralen/faq.html', {
# 		evalScripts:true,
# 		parameters:'subcatid='+undercatid,
# 		onSuccess: function() {
# 			$('kontaktInfo').hide();
# 			$('mcRubrik').hide();
# 		$('mcFragor').show();
# 			$('mcPlusBild').className = 'rubPlus';
# 		}
# 	});
# }
#
#
# function mcskickafunction() {
# 	if (document.mail.maincatid && document.mail.maincatid.value.length <1) {
# 		alert ('Du må velge en hovedkategori for meldingen din.');
# 		document.mail.maincatid.focus();
# 		return false;
# 	}
# 	if (document.mail.sender_email && !(/^\w+([\.\-\+\|\#]?\w+)*@\w+([\.\-]?\w+)*(\.\w{2,4})+$/.test(document.mail.sender_email.value))) {
# 		alert('Du må fylle inn en e-post adresse');
# 		document.mail.sender_email.focus();
# 		return false;
# 	}
# 	if (document.mail.errand && document.mail.errand.value == "") {
# 		alert('Vennligst angi et emne');
# 		document.svaramail.errand.focus();
# 		return false;
# 	}
# 	if (document.mail.message && document.mail.message.value == "") {
# 		alert('Vennligst skriv inn meldingen');
# 		document.mail.message.focus();
# 		return false;
# 	}
#
#
# 	//flush browser cache
# 	if($('maincatid')){ //kundservice
# 		var key1 = "mittsvar_"+$('maincatid').value;
# 		var key2 = "errand_"+$('maincatid').value;
# 		deletMsgContent(key1);
# 		deletMsgContent(key2);
# 	}else if($('unid')){ //svara
# 		var key = $('unid').value;
# 		deletMsgContent(key);
# 	}
#
# 	new Ajax.Updater('mcformular','/mux/ajax/meddelandecentralen/skickaMail.html', {
# 		parameters: document.mail.serialize()
# 	});
# }
#
# /* depricated
# function mcsvarafunction() {
# 	if (document.svaramail.errand.value == "") {
# 		alert('Vennligst angi et emne');
# 		document.svaramail.errand.focus();
# 		return false;
# 	}
# 	if (document.svaramail.mittsvar.value == "") {
# 		alert('Vennligst skriv inn meldingen');
# 		document.svaramail.mittsvar.focus();
# 		return false;
# 	}
# 	new Ajax.Updater('mcsvaraDiv','/mux/ajax/meddelandecentralen/svaraMail.html', {parameters: document.svaramail.serialize()});
# }
# */
# </script>
# <nav style="position:relative; z-index:12;">
# <div><!-- IE --></div>
# <div id="menyPortalNordnet" style="display:none">
# <div class="shadowCorner">
# <div class="shadow">
# <div class="mpContent">
# <a class="close" href="#" onclick="mainMenu.close('Nordnet')"><img alt="" class="close" src="/now/images/knappClose.gif" title="Stäng"/></a>
# <div class="module onecol">
# <div class="grey"><h2>Kontotyper</h2></div>
# <div class="submodule">
# <a href="/aksjesparekonto/aksjesparekonto-hovedside.html">Aksjesparekonto</a><span class="ny">Ny!</span><br/>
# <a href="/tjenester/kontotyper/aksje--og-fondskonto.html">Aksje- og fondskonto</a><br/>
# <a href="/tjenester/kontotyper/investeringskonto-zero.html">Investeringskonto Zero</a><br/>
# <a href="/tjenester/kontotyper/sparekonto.html">Sparekonto</a><br/>
# <a href="/tjenester/kontotyper/active-trader.html">Active Trader</a><br/>
# <a href="/tjenester/kontotyper/private-banking.html">Private Banking</a><br/>
# <a href="/tjenester/kontotyper/under-18.html">Under 18</a><br/>
# <a href="/tjenester/kontotyper/bedriftskunde.html">Bedriftskunde</a><br/>
# <a href="/tjenester/kontotyper/student.html">Student</a><br/>
# </div>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Pensjon</h2></div>
# <div class="submodule">
# <a href="/tjenester/pensjon/ipa.html">IPA</a><br/>
# <a href="/tjenester/pensjon/ips.html">IPS</a><br/>
# <a href="/tjenester/pensjon/pensjonskapitalbevis.html">Pensjonskapitalbevis</a><br/>
# <a href="/tjenester/pensjon/pensjonssparing.html">Pensjonssparing</a><br/>
# </div>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Investeringer</h2></div>
# <div class="submodule">
# <a href="/tjenester/investeringer/aksjer.html">Aksjer</a><br/>
# <a href="/tjenester/investeringer/fond.html">Fond</a><br/>
# <a href="/tjenester/investeringer/borsnoterte-fond.html">Børsnoterte fond</a><br/>
# <a href="/tjenester/investeringer/derivater.html">Derivater</a><br/>
# <a href="/tjenester/investeringer/tradingprodukter.html">Tradingprodukter</a><br/>
# <a href="/tjenester/investeringer/ravarer.html">Råvarer</a><br/>
# <a href="/tjenester/investeringer/rentesparing.html">Rentesparing</a><br/>
# <a href="/tjenester/investeringer/belaning.html">Belåning</a><br/>
# <a href="/kampanjer/superlanet.html">Superlånet</a><br/>
# <a href="/superfondet">Superfondet</a><br/>
# <a href="/nordnetmarkets">Nordnet Markets</a><span class="ny">Ny!</span><br/>
# <a href="/tjenester/shareville/shareville.html">Shareville</a><br/>
# <a href="/tjenester/analyse-og-verktoy/fondsradgiveren.html">Fondsrådgiveren</a><span class="ny">Ny!</span><br/>
# </div>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Analyse og verktøy</h2></div>
# <div class="submodule">
# <a href="/tjenester/analyse-og-verktoy/handelstjenester.html">Handelstjenester</a><br/>
# <a href="/tjenester/analyse-og-verktoy/markedsinformasjon.html">Markedsinformasjon</a><br/>
# <a href="/tjenester/analyse-og-verktoy/automatisk-handel.html">Automatisk handel</a><br/>
# <a href="/tjenester/analyse-og-verktoy/teknisk-analyse.html">Teknisk analyse</a><br/>
# <a href="/tjenester/analyse-og-verktoy/investeringstips.html">Investeringstips</a><br/>
# <a href="/tjenester/analyse-og-verktoy/nordnetskolen.html">Kurs og seminarer</a><br/>
# </div>
# </div>
# <div class="enclosing"></div>
# <div class="xtraContent" id="prodXtra" style="display:block;">
# <div class="module fourcol">
# <div class="submodule meny">
# <a href="/tjenester/prisliste.html">Prisliste
# 			</a><span class="bullet">·</span>
# <a href="/tjenester/skjema.html">Skjema</a>
# <span class="bullet">·</span>
# <a href="/kundeservice/start.html">Kundeservice</a>
# <span class="bullet">·</span>
# <a href="/kampanjer/flytteservice.html">Flytteservice</a>
# <span class="bullet">·</span>
# <a href="https://www.finansportalen.no/">Finansportalen</a>
# </div>
# </div>
# </div>
# <div class="enclosing"></div>
# </div>
# </div>
# </div>
# </div>
# <div><!-- IE --></div>
# <div id="menyPortalDepa" style="display:none">
# <div class="shadowCorner">
# <div class="shadow">
# <div class="mpContent">
# <a class="close" href="#" onclick="mainMenu.close('depa')"><img alt="Steng" class="close" src="/now/images/knappClose.gif" title="Steng"/></a>
# <div class="module onecol">
# <div class="grey"><h2>Min portefølje</h2></div>
# <a class="notYet" href="/mux/web/depa/mindepa/depaoversikt.html" rel="nofollow">Kontooversikt</a><br/>
# <a class="notYet" href="/mux/web/depa/mindepa/valutor.html" rel="nofollow">Valutakonto</a><br/>
# <a class="notYet" href="/mux/web/depa/mindepa/transaktionerNotor.html" rel="nofollow">Transaksjoner og sluttsedler</a><br/>
# <a class="notYet" href="/mux/web/depa/mindepa/krediter.html" rel="nofollow">Belåningsoversikt</a><br/>
# <a class="notYet" href="/mux/web/depa/mindepa/portfoljRapportStart.html" rel="nofollow">Porteføljerapport</a><br/>
# <a class="notYet" href="/mux/web/depa/minsida.html" rel="nofollow">Startsiden</a><br/>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Corporate actions</h2></div>
# <a class="notYet" href="/mux/web/depa/minaForetagshandelser.html" rel="nofollow">Mine corporate actions</a><br/>
# <a class="notYet" href="/mux/web/depa/handelser/ipos/aktuella.html" rel="nofollow">Børsnoteringer</a><br/>
# <a class="notYet" href="/mux/web/depa/ovrigaForetagshandelser.html" rel="nofollow">Øvrige corporate actions</a><br/>
# <br/>
# <div class="grey"><h2>Flytte til Nordnet</h2></div>
# <a class="notYet" href="/mux/web/depa/flyttatillnordnet/flyttaVardepapper.html" rel="nofollow">Overføre verdipapirer</a><br/>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Overføringer</h2></div>
# <a class="notYet" href="/mux/web/depa/overforingar/insattningar.html" rel="nofollow">Innskudd / Avtalegiro</a><br/>
# <a class="notYet" href="/mux/web/depa/overforingar/uttag.html" rel="nofollow">Uttak</a><br/>
# <a class="notYet" href="/mux/web/depa/overforingar/foranmaldaKontonNO.html" rel="nofollow">Registrer en bankkonto for uttak</a><br/>
# <a class="notYet" href="/mux/web/depa/overforingar/flyttaInternt.html" rel="nofollow">Overfør mellom Nordnet-kontoer</a><br/>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Øvrig</h2></div>
# <span class="notYet"><a href="/portfolioreport/yearlystatement.html">Årsoppgave</a><br/></span>
# <a class="notYet" href="/mux/web/depa/avtalabon/avtalAbonnemang.html" rel="nofollow">Mine avtaler og abonnement</a><br/>
# <a class="notYet" href="/mux/web/depa/installningar/installningar.html" rel="nofollow">Innstillinger</a><br/>
# </div>
# <div class="enclosing"></div>
# </div>
# </div>
# </div>
# </div>
# <div><!-- IE --></div>
# <div id="menyPortalMarknaden" style="display:none">
# <div class="shadowCorner">
# <div class="shadow">
# <div class="mpContent">
# <a class="close" href="#" onclick="mainMenu.close('marknaden')"><img alt="Steng" class="close" src="/now/images/knappClose.gif" title="Steng"/></a>
# <div class="module onecol">
# <div class="grey"><h2>Alle kurslister</h2></div>
# <a class="notYet" href="/mux/web/marknaden/kurslista/minaListor.html">Mine lister</a><br/>
# <a href="/mux/web/marknaden/kurslista/aktier.html">Aksjekurser</a><br/>
# <a href="/mux/web/marknaden/kurslista/optioner.html">Opsjoner</a><br/>
# <a href="/marknaden/kurslista/rantebevis.html">Rentebevis</a><br/>
# <br/>
# <div class="grey"><h2>Nordnet Markets<span class="ny">Nyhet!</span></h2></div>
# <a href="/nordnetmarkets">Om Nordnet Markets</a><br/>
# <a href="/mux/web/marknaden/nordnetmarkets/certificates.html">Bull &amp; Bear (ETN)</a><br/>
# <a href="/mux/web/marknaden/nordnetmarkets/futures.html">Mini Futures</a><br/>
# <a href="https://bank.nordea.no/apps/dwa/knocked-nordnet-mini-futures.html" rel="noopener noreferrer" target="_blank">Knockede produkter</a><br/>
# <a href="https://bank.nordea.no/apps/dwa/matured-nordnet-mini-futures.html" rel="noopener noreferrer" target="_blank">Forfalte produkter</a><br/>
# <br/>
# <div class="grey"><h2>ETF</h2></div>
# <a href="/etf/center?etf=true&amp;cert=false&amp;lev=true&amp;search=true">Børsnoterte fond (ETF)</a><br/>
# <br/>
# <br/>
# <div class="grey"><h2>Øvrige investeringer</h2></div>
# <a href="/rantetorget/rantetorget.html">Rentetorget</a><br/>
# <a href="/mux/web/marknaden/kurslista/warranter.html">Tradingprodukter</a><br/>
# </div>
# <div class="module twocol">
# <div class="grey"><h2>Markedsoversikt</h2></div>
# <a class="flagNo" href="/mux/web/marknaden/marknadsoversikt/marknadsoversiktNO.html"><span>Norge</span></a>
# <a class="flagSe" href="/mux/web/marknaden/marknadsoversikt/marknadsoversiktSE.html"><span>Sverige</span></a>
# <a class="flagDk" href="/mux/web/marknaden/marknadsoversikt/marknadsoversiktDK.html"><span>Danmark</span></a>
# <a class="flagFi" href="/mux/web/marknaden/marknadsoversikt/marknadsoversiktFI.html"><span>Finland</span></a>
# <a class="flagDe" href="/mux/web/marknaden/marknadsoversikt/marknadsoversiktDE.html"><span>Tyskland</span></a>
# <a class="ikonNordamerika" href="/mux/web/marknaden/marknadsoversikt/marknadsoversiktUS.html"><span>Nord-Amerika</span></a>
# <a class="ikonNorden" href="/mux/web/marknaden/marknadsoversikt/marknadsoversiktNORDEN.html"><span>Norden</span></a>
# <div class="world">
# <a class="ikonVarlden" href="/mux/web/marknaden/varlden/karta.html">Verden</a>
# <span class="bullet">·</span>
# <a href="/mux/web/marknaden/varlden/index.html">Indeks</a>
# <span class="bullet">·</span>
# <a href="/mux/web/marknaden/varlden/rantor.html">Renter</a>
# <span class="bullet">·</span>
# <a href="/mux/web/marknaden/varlden/ravaror.html">Råvarer</a>
# <span class="bullet">·</span>
# <a href="/mux/web/marknaden/varlden/valutor.html">Valuta</a>
# </div>
# <br/>
# <div class="grey"><h2>Markedsinformasjon</h2></div>
# <table>
# <tr>
# <td><a href="/mux/web/marknaden/marknadsinformation/vinnareforlorare.html">Vinnere &amp; tapere</a></td>
# <td><a href="/mux/web/marknaden/marknadsinformation/maklarstatistik/index.html">Meglerstatistikk</a></td>
# <td><a href="/mux/web/marknaden/marknadsinformation/mestomsatta/mestomsatta.html">Mest omsatt</a></td>
# </tr><tr>
# <td><a href="/mux/web/marknaden/marknadsinformation/handelskalender.html">Handelskalender</a></td>
# </tr><tr>
# <td colspan="3">
# <a href="#" onclick="window.open('/mux/page/skankautdelning/dividends.html?country=NO', 'listWindow', 'scrollbars=yes, resizable=yes, toolbar=nries=no, status=no,menubar=no,width=1050,height=700,screenY=50,screenX=100'); return false;">
# 						Kommende generalforsamlinger og utbytte<img alt="Öppna i nytt babel&gt;" src="/now/images/knappPopup2.gif" style="padding-left: 4px;" title="Åpne i nytt vindu"/>
# </a>
# </td>
# </tr>
# </table>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Alarm</h2></div>
# <a class="notYet" href="/mux/web/marknaden/larmOchRapporter/minaLarmOchRapporter.html" rel="nofollow">Mine alarmer &amp; rapporter</a><br/>
# <a class="notYet" href="/mux/web/marknaden/larmOchRapporter/kursLarm.html" rel="nofollow">Opprett kursalarm</a><br/>
# <a class="notYet" href="/mux/web/marknaden/larmOchRapporter/kursRapport.html" rel="nofollow">Opprett kursrapport</a><br/>
# <a class="notYet" href="/mux/web/marknaden/larmOchRapporter/nyhetsLarm.html" rel="nofollow">Opprett nyhetsalarm</a><br/>
# <a class="notYet" href="/mux/web/marknaden/larmOchRapporter/depaRapport.html" rel="nofollow">Bestill kontorapport</a><br/>
# <a class="notYet" href="/mux/web/marknaden/larmOchRapporter/indexRapport.html" rel="nofollow">Bestill indeksrapport</a><br/>
# <a href="/mux/web/nordnet/morning-letter.html" rel="nofollow">Bestill Morgenrapport</a><br/>
# </div>
# <div class="enclosing"></div>
# </div>
# </div>
# </div>
# </div>
# <div><!-- IE --></div>
# <div id="menyPortalFonder" style="display:none">
# <div class="shadowCorner">
# <div class="shadow">
# <div class="mpContent">
# <a class="close" href="#" onclick="mainMenu.close('fonder')"><img alt="Steng" class="close" src="/now/images/knappClose.gif" title="Steng"/></a>
# <div class="module twocol fonder">
# <div class="grey"><h2>Oversikt</h2></div>
# <a href="/mux/web/fonder/oversikt.html">Fondstorget</a><br/>
# <a class="newWin" href="http://www.altomfond.no" target="_blank">Til Altomfond.no</a><br/>
# <a href="/mux/web/fonder/fondmarknader.html">Fondsmarkeder</a><br/>
# <div class="grey"><h2>Investeringsrådgivning</h2></div>
# <a href="/tjenester/analyse-og-verktoy/fondsradgiveren.html">Fondsrådgiveren</a><br/>
# </div>
# <div class="module twocol fonder ">
# <div class="grey"><h2>Fondstorget</h2></div>
# <a href="/mux/web/fonder/nordnetTopp30.html">Topp 30</a><br/>
# <a href="/mux/web/fonder/fondportfoljer.html">Nordnets fondsporteføljer</a><br/>
# <a href="/mux/web/fonder/oversiktSok.html">Søk fond</a><br/>
# <a href="/mux/web/fonder/topplistor.html">Topplister</a><br/>
# <a href="/superfondet">Superfondet</a><br/>
# </div>
# <div class="module onecol fonder">
# <div class="grey"><h2>Analysere</h2></div>
# <a class="notYet" href="/mux/web/fonder/jamforFonder.html">Sammenlign fond</a><br/>
# <!--a href="/mux/web/nordnet/underConstruction.html" class="notYet">Porteføljeanalyse</a><br /-->
# </div>
# <div class="enclosing"></div>
# </div>
# </div>
# </div>
# </div>
# <div><!-- IE --></div>
# <div id="menyPortalHandla" style="display:none">
# <div class="shadowCorner">
# <div class="shadow">
# <div class="mpContent">
# <a class="close" href="#" onclick="mainMenu.close('handla')"><img alt="Steng" class="close" src="/now/images/knappClose.gif" title="Steng"/></a>
# <div class="module onecol">
# <div class="grey"><h2>Aksjer</h2></div>
# <a class="notYet" href="/mux/web/handla/kopAktier.html" rel="nofollow">Kjøp og selg aksjer</a><br/>
# <a class="notYet" href="/mux/web/handla/handla.html?isStoploss=1" rel="nofollow">Stop Loss</a><br/>
# <div data-countrycode="NO" data-lang="no" id="iwt-redirect-button"></div>
# <script src="/sc/iwt-link/init/index.js"></script>
# <script>
#         	(function(window, document) {
#           		var appName = 'iwt-redirect-button';
#           		var domElement = document.getElementById(appName);
#           		if (domElement && window.Nordnet[appName]) {
#             			window.Nordnet[appName](domElement);
#           		}
#         	})(window, document);
#       	</script>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Fond</h2></div>
# <a class="notYet" href="/mux/web/handla/kopFonder.html" rel="nofollow">Kjøp fond</a><br/>
# <a class="notYet" href="/mux/web/handla/saljFonder.html" rel="nofollow">Selg fond</a><br/>
# <a class="notYet" href="/mux/web/handla/bytFonder.html" rel="nofollow">Bytt fond</a><br/>
# <span class="notYet"><a href="/manadsspar">Spareavtale</a><br/></span>
# <span class="notYet"><a href="/manadsspar/etf">Spareavtale i ETF</a><br/></span>
# <a class="notYet" href="/mux/web/fonder/buyETF.html" rel="nofollow"></a><br/>
# </div>
# <div class="module onecol">
# <div class="grey"><h2>Ordrer og handler</h2></div>
# <a class="notYet" href="/mux/web/handla/orderbok/orderbok.html" rel="nofollow">Mine ordre og handler</a><br/>
# </div>
# <div class="enclosing"></div>
# </div>
# </div>
# </div>
# </div>
# <div><!-- IE --></div>
# <div id="menyPortalAnalys" style="display:none">
# <div class="shadowCorner">
# <div class="shadow">
# <div class="mpContent">
# <a class="close" href="#" onclick="mainMenu.close('analys')"><img alt="" class="close" src="/now/images/knappClose.gif" title="Steng"/></a>
# <div class="module onecol">
# <div class="grey"><h2>Nyheter og pressemeldinger</h2></div>
# <a href="/mux/web/analys/nyheter/nyheterPressmeddelanden.html">Nyheter og pressemeldinger</a><br/>
# <a href="/mux/web/analys/nyheter/finanskalender.html">Finanskalender</a><br/>
# <a href="/mux/web/analys/nyheter/investtech.html">Investtech - teknisk analyse</a><br/>
# <a class="newWin" href="http://nordnetbloggen.no/" target="_blank">Nordnetbloggen.no</a>
# <br/>
# </div><!-- /module onecol -->
# <div class="module threecol">
# <div class="grey"><h2>Aksjetips og analyse</h2></div>
# <a class="experterna" href="/mux/web/analys/experterna/oversikt.html">Oversikt Aksjetips og analyse</a> <div class="enclosing"></div>
# <div class="grey"><h2>Utfordrerne</h2></div>
# </div><!-- /module threecol -->
# <div class="enclosing"></div>
# </div>
# </div>
# </div>
# </div>
# <div><!-- IE --></div>
# </nav>
# <a href="#" onfocus="blur()" tabindex="1000"></a>
# <a accesskey="ö" href="/mux/web/depa/mindepa/depaoversikt.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="t" href="/mux/web/depa/mindepa/transaktionerNotor.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="l" href="/mux/web/marknaden/kurslista/minaListor.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="k" href="/mux/web/marknaden/kurslista/aktier.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="m" href="/mux/web/marknaden/marknadsoversikt/marknadsoversiktNO.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="h" href="/mux/web/handla/kopAktier.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="o" href="/mux/web/handla/orderbok/orderbok.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="n" href="/mux/web/analys/nyheter/nyheterPressmeddelanden.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="a" href="/mux/web/analys/nyheter/analyser.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="e" href="/mux/web/analys/experterna/oversikt.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="v" href="/mux/web/marknaden/varlden/varlden.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="x" href="/mux/web/depa/mindepa/valutor.html" onfocus="document.location=this.href" tabindex="1001"></a>
# <a accesskey="q" href="#" onfocus="popupQuickTrade('/mux/page/quicktrade.html','QuickTrade','504','760','yes','center'); return false" tabindex="1001"></a>
# <a accesskey="s" href="#" onfocus="supportNavWidget.open('fastSeek', event)" tabindex="1001"></a>
# </div>
# </div>
# <div id="container">
# <script src="/now/js/mCentralen.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# function createIMGnode(uid,target){
#
# 	var elmId = "del_"+uid+"_"+target;
# 	var wrapperId = uid+"_"+target;
#
# 	new Insertion.After('uploadFeedback', "<div id="+wrapperId+" class='mcUpload' >"+target+"   <a id="+elmId+" class='mcTrash' href='#'>&nbsp;&nbsp;</a> </div>");
# 	new Insertion.After(elmId, "<div class='enclosing'></div>");
# 	$(elmId).onclick = function() {
# 		deleteIMG(uid,target);
# 		return false;
# 	};
#
# 	removeSpinner();
#
# }
# function displayErrorMsg(errmsg){
# 	$('uploadHaltText').update(errmsg);
# 	$('uploadHalt').show();
# 	removeSpinner();
# }
#
# function removeSpinner (){
# 	$('loadingImg').remove();
# 	$('filen').enable();
# }
#
#
# function deleteIMG(uid,target){
#
# 	var action = 'del_img';
# 	var wrapperId = uid+"_"+target;
# 	var url = "/mux/ajax/meddelandecentralen/bifogaFil.html";
# 	new Ajax.Request(url, {
# 	    parameters:'uid='+uid+'&action='+action+'&target='+target,
# 	    evalScripts:true,
#
# 	    onSuccess: function(transport) {
# 			var result = transport.responseText;
# 			$(wrapperId).remove();
# 			resetFormElement($('filen'));
# 		}
# 	});
# }
# function resetFormElement(e) {
#  	jQuery(e).wrap('<form>').closest('form').get(0).reset();
#   	jQuery(e).unwrap();
# }
#
#
#
# function bytMcKontakt(obj,klassOn,klassOff,lager){
# 	var lagerStyle = document.getElementById(lager).style;
# 	obj.className = (obj.className != klassOn) ? klassOn : klassOff;
# 	lagerStyle.display = (lagerStyle.display != "none") ? "none" : "block";
# 	mcShake();
# }
#
# function mcHamtaFragor(varde,gommaLager,visaLager,bild,gommaLager2){
# var mcBild = document.getElementById(bild);
# var div1 = document.getElementById(gommaLager).style;
# var div2 = document.getElementById(gommaLager2).style;
# var lager = document.getElementById(visaLager).style;
# 	if (varde!=0) {
# 		div1.display="none";
# 		div2.display="none";
# 		lager.display="block";
# 		mcBild.className = 'rubPlus';
# 	}
# 	else {
# 		div1.display="block";
# 		div2.display="block";
# 		lager.display="none";
# 		mcBild.className = 'rubMinus';
# 	}
# 	mcShake();
# }
#
# function changesubcat() {
# 	var maincatid = $F('maincatid');
# 	new Ajax.Updater('underkategori', '/mux/ajax/meddelandecentralen/undercat.html', {
# 		evalScripts:true,
# 		parameters:'maincatid='+maincatid
# 	});
# }
#
# function changefaq() {
# 	var undercatid = $F('subcatid');
# 	new Ajax.Updater('mcFragor', '/mux/ajax/meddelandecentralen/faq.html', {
# 		evalScripts:true,
# 		parameters:'subcatid='+undercatid,
# 		onSuccess: function() {
# 			$('kontaktInfo').hide();
# 			$('mcRubrik').hide();
# 		$('mcFragor').show();
# 			$('mcPlusBild').className = 'rubPlus';
# 		}
# 	});
# }
#
#
# function mcskickafunction() {
# 	if (document.mail.maincatid && document.mail.maincatid.value.length <1) {
# 		alert ('Du må velge en hovedkategori for meldingen din.');
# 		document.mail.maincatid.focus();
# 		return false;
# 	}
# 	if (document.mail.sender_email && !(/^\w+([\.\-\+\|\#]?\w+)*@\w+([\.\-]?\w+)*(\.\w{2,4})+$/.test(document.mail.sender_email.value))) {
# 		alert('Du må fylle inn en e-post adresse');
# 		document.mail.sender_email.focus();
# 		return false;
# 	}
# 	if (document.mail.errand && document.mail.errand.value == "") {
# 		alert('Vennligst angi et emne');
# 		document.svaramail.errand.focus();
# 		return false;
# 	}
# 	if (document.mail.message && document.mail.message.value == "") {
# 		alert('Vennligst skriv inn meldingen');
# 		document.mail.message.focus();
# 		return false;
# 	}
#
#
# 	//flush browser cache
# 	if($('maincatid')){ //kundservice
# 		var key1 = "mittsvar_"+$('maincatid').value;
# 		var key2 = "errand_"+$('maincatid').value;
# 		deletMsgContent(key1);
# 		deletMsgContent(key2);
# 	}else if($('unid')){ //svara
# 		var key = $('unid').value;
# 		deletMsgContent(key);
# 	}
#
# 	new Ajax.Updater('mcformular','/mux/ajax/meddelandecentralen/skickaMail.html', {
# 		parameters: document.mail.serialize()
# 	});
# }
#
# /* depricated
# function mcsvarafunction() {
# 	if (document.svaramail.errand.value == "") {
# 		alert('Vennligst angi et emne');
# 		document.svaramail.errand.focus();
# 		return false;
# 	}
# 	if (document.svaramail.mittsvar.value == "") {
# 		alert('Vennligst skriv inn meldingen');
# 		document.svaramail.mittsvar.focus();
# 		return false;
# 	}
# 	new Ajax.Updater('mcsvaraDiv','/mux/ajax/meddelandecentralen/svaraMail.html', {parameters: document.svaramail.serialize()});
# }
# */
# </script>
# <div class="wrapIframe">
# <iframe frameborder="0" height="1009" id="morningstar" scrolling="no" src="https://secust.msse.se/se/nordnetny/funds/overview.aspx?cid=FXLUX01630&amp;cntry=NO&amp;IPS=1&amp;istopp3=&amp;expert=&amp;nnkat=&amp;site=no&amp;lang=no&amp;orderaction=onlybuy" width="1010"></iframe>
# </div><!-- /wrapIframe -->
# <div class="enclosing"></div>
# </div><!-- SLUT CONTAINER -->
# <div class="disclaimer risk">
# <p>Finansielle verdipapirer kan både øke og minke i verdi. Det er en risiko for at du ikke får tilbake pengene du har investert. Før du investerer i et fond bør du lese prospektet som er tilgjengelig hos fondsforvalter og nøkkelinformasjonen du finner på ordreleggingssiden og på fondets produktside på nordnet.no.</p>
# </div>
# <footer>
# <div id="footerContainer">
# <a href="//nordnet.humany.net/floating-no" style="display:none">Kundeservice</a>
# <div class="footerLinks">
# <div class="col4">
# <ul>
# <li><a href="/tjenester/prisliste.html">Prisliste</a></li>
# <li><a href="/tjenester/skjema.html">Skjema</a></li>
# <li><a href="/footer/skatt.html">Skatt og skattemelding (selvangivelse)</a></li>
# <li><a href="/kampanjer/arsskiftet.html">Årsskiftet 2017/2018</a></li>
# </ul>
# </div>
# <div class="col4">
# <ul>
# <li><a href="/footer/sikkerhet-og-garanti.html">Sikkerhet og garanti</a></li>
# <li><a href="/footer/investorbeskyttelse.html">Investorbeskyttelse</a></li>
# <li><a href="/footer/tiltak-mot-hvitvasking.html">Tiltak mot hvitvasking</a></li>
# <li><a href="/footer/fatca---en-amerikansk-lov.html">FATCA  en amerikansk lov</a></li>
# </ul>
# </div>
# <div class="col4">
# <ul>
# <li><a href="/footer/reklamasjoner.html ">Reklamasjoner</a></li>
# <li><a href="https://www.nordnet.no/footer/forsikringsagentregister.html" target="_blank">Forsikringsagentregister</a></li>
# <li><a href="https://www.nordnet.no/footer/provisjon.html" target="_blank">Informasjon om provisjon og godtgjørelse</a></li>
# <li><a href="https://www.nordnet.no/footer/personopplysninger.html"> Personopplysningene</a></li> <br/>
# </ul>
# </div>
# </div>
# <div class="enclosing"></div>
# <div class="footerContact">
# <div class="col4">
# <img alt="" class="footline" src="/now/images/footDividerSmall.png"/>
# <h6>BESØKSADRESSE</h6>
# <p>
# 					Nordnet<br/>Akersgata 45<br/>0158 Oslo
# 				</p>
# <h6 class="next">POSTADRESSE</h6>
# <p>Nordnet<br/>Postboks 302 Sentrum<br/>0103 Oslo</p>
# </div>
# <div class="col4">
# <img alt="" class="footline" src="/now/images/footDividerSmall.png"/>
# <h6><a href="https://www.nordnet.no/kundeservice/start.html?cmpi=customer-service-NO-footer">Kundeservice</a></h6>
# <dl>
# <dt>Mandag - fredag</dt><dd>8.30 - 17.00</dd>
# <dt>Meglerbordet</dt><dd>8.30 - 22.00</dd>
# <a class="btn-primary" href="https://www.nordnet.no/kundeservice/start.html?cmpi=customer-service-NO" style="font-size: 12px; margin: 5px 0 0 24px;">Kontakt oss</a>
# </dl>
# </div>
# <div class="col4">
# <img alt="" class="footline" src="/now/images/footDividerSmall.png"/>
# <h6>Informasjon</h6>
# <div>
# <ul>
# <li><a href="https://www.nordnet.no/footer/disclaimer.html?cmpi=start-disclaimer">Disclaimer</a></li>
# <li><a href="/mux/web/info/cookies.html?cmpi=start-cookies">Om cookies</a></li>
# <li><a href="https://www.finansportalen.no/">Sammenlign priser hos Finansportalen</a></li>
# </ul>
# </div>
# <div>
# <ul>
# <li><a href="http://nordnetab.com/about/nordnet-overview" target="_blank">Om Nordnet</a></li>
# <li><a href="http://nordnetab.com/careers/working-at-nordnet" target="_blank">Jobb i Nordnet</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footerSocial">
# <img alt="" class="footline" src="/now/images/footDividerLarge.png"/>
# <div class="col8">
# 				 <!--h6>Awards</h6-->
# </div>
# <div class="col 4 followUs">
# <h6>Følg oss på</h6>
# <div class="iconLarge">
# <p>
# <a class="follow Nblog" href="http://www.nordnetbloggen.no/" target="_blank" title="Nordnetbloggen"></a>
# <a class="follow FB" href="http://www.facebook.com/Nordnetnorge?sk=wall" target="_blank" title="Nordnet Facebook"></a>
# <a class="follow Twttr" href="http://twitter.com/nordnetno" target="_blank" title="Nordnet Twitter"></a>
# <a class="follow Instgr" href="http://instagram.com/nordnet#" target="_blank" title="Nordnet Instagram"></a>
# <a class="follow YouTube" href="https://www.youtube.com/user/NordnetNorge" target="_blank" title="Nordnet YouTube"></a>
# <a class="follow SlideShare" href="http://www.slideshare.net/Nordnetnorge" target="_blank" title="Nordnet SlideShare"></a>
# </p>
# </div>
# <div class="enclosing"></div>
# <div class="iconSmall">
# <ul>
# <li class="Twttr"><a href="https://twitter.com/andersnordnet" target="_blank" title="Følj Anders Skar på Twitter">Anders Skar, Landssjef</a></li>
# <li class="Twttr"><a href="https://twitter.com/BjornNordnet" target="_blank" title="Følj Spareøkonom på Twitter">Bjørn Erik Sættem, Spareøkonom</a></li>
# </ul>
# </div>
# </div>
# </div><!-- /footerSocial -->
# </div><!-- /footerContainer -->
# </footer><!-- /foot -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-NXLM4W" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script src="/sc/tracking-js/init/base.js" type="text/javascript"></script>
# <script>
#     var gtmArgs = { logged_in: false };
#     if (typeof tracking === 'object' && typeof tracking.initGTM === 'function') {
#       tracking.initGTM(gtmArgs);
#     }
#   </script>
# <link href="/now/css/humany.css" rel="stylesheet" type="text/css"/>
# <!-- Start: Google Analytics for Humany widget -->
# <script>
# 		(function () {
# 			var humanyTracker = "";
#
# 			//// Use this for separate tracker
# 			//window.ga && ga('create', 'UA-XXXXX-Y', 'auto', 'humany');
# 			//humanyTracker = "humany.";
#
# 			var GaPlugin = {
# 				name: "tracking.ga",
# 				init: function (data, context) {
# 					context.router.on("change", function (route) {
# 						var qs = $.extend({}, route.params); delete qs.id, delete qs.uriName;
# 						var url = route.widgetName + "/" + route.name + "/" + route.params.id + "/" + route.params.uriName + "?" + $.param(qs);
# 						window.ga && ga(humanyTracker + 'send', 'pageview', url);
# 					});
# 				}
# 			}
#
# 			Humany.configure(function(config){
# 				config.registerPlugin(GaPlugin);
# 			});
#
# 		})();
# 		</script>
# <!-- End: Google Analytics for Humany widget -->
# <!-- Start Humany - implementation: "default" -->
# <script>
# 		  (function(n,t,i,r,u,f,e){for(var o,s=/[?&]{1}(humany[^=]*)=([^&#]*)/g;o=s.exec(n.location.search);)i+=(i.indexOf("?")>-1?"&":"?")+o[1]+"="+o[2];
# 		  f=t.createElement(u);f.async=!0;f.src=i;e=t.getElementsByTagName(u)[0];e.parentNode.insertBefore(f,e);n[r]=n[r]||{_c:[],configure:function(t){n[r]._c.push(t)}}})
# 		  (window,document,"//nordnet.humany.net/default/embed.js","Humany","script");
# 		</script>
# <script>
# 		   Humany.configure(function (config) {
# 		      config.useCors(false);
# 		   });
# 		</script>
# <!-- End Humany -->
# <iframe height="1" id="printFrame" name="printFrame" src="" style="border:0px;" width="1"></iframe>
# <div class="enclosing"></div>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1032173120/?value=1.000000&amp;label=b2YzCJTo4AcQwOyW7AM&amp;guid=ON&amp;script=" style="border-style:none;" width="1"/>
# </div>
# <!--[if lte IE 8]>
# <script>
# 	// marking page as loaded in old browser
# 	document.getElementsByTagName('html')[0].className = 'ie8';
# </script>
# <![endif]-->
# <script src="/now/js/cookies.js" type="text/javascript"></script>
# </body>
# </html>

# %% [markdown]
# We now have a slightly harder problem to solve, as some of the data we need is hidden by a navigation tab on the detail page. In fact they're "hidden" under an `<iframe/>` tag which we'll extract.
#
# ![Screenshot%20from%202018-07-23%2021-45-49.png](attachment:Screenshot%20from%202018-07-23%2021-45-49.png)
#
# We need the data in the tab "Innhold"!
#
# As we click on the navigation-tabs, we see that the URL of the browser doesn't change, i.e the information displayed in the "Innhold"-tab should be available in the HTML if we're lucky.
#
# Using the inspection-tool in the browser we find that the information in the "Innhold"-tab is refrenced with an URL!
#
# ![Screenshot%20from%202018-07-23%2021-52-34.png](attachment:Screenshot%20from%202018-07-23%2021-52-34.png)
#
# We already know how to extract theese with BeautifulSoup, so let's do that!

# %%
iframe_element = soup.find(lambda tag: tag.name == "iframe")

# %%
overview_url = iframe_element.get('src')
portifolio_url = "https://secust.msse.se/se/nordnetny/funds/portfolio" + overview_url.split("overview")[1]

overview_soup = BeautifulSoup(requests.get(overview_url).text, 'lxml')
portifolio_soup = BeautifulSoup(requests.get(portifolio_url).text, 'lxml')

# %% [markdown]
# <h3> Checkpoint Alfa </h3>
#
# Okay, so now we got two soups, one for each of the tabs we need!
#
# Next, we'll go through theese two soups to try to fetch out the data we're interested in!
#
# The plan is to put all of this information, for every fund available, into a Pandas dataframe. From there it will be a lot easier to handle and serve the date to the next step of this project.

# %%
cost_table_soup = overview_soup.find("h2", text = "Maks kjøpsavgift").next_sibling.next_sibling

# This gives us the table we want to look at first, the costs of investing in the fund 

row_names = ["Kjøp", "Selg", "Forvaltningsavgift", "Resultatbasert avgift(maks)", "Løpende kostnader"]
td_tags = cost_table_soup.findAll("td", class_=None)

#Regex to find the values in the td_tags, or insert '-' if no value
values = [re.findall("\d+\.\d+", text.text)[0] if re.findall("\d+\.\d+", text.text) else '0'  for text in td_tags]

columns = ['Kjøpsavgift', "Salgsavgift", "Forvaltningsavgift", "Resultatbastert avgift(maks)", "Løpende kostnader"]

# Creating the dictionary in which our data lies, which will be used to initiate the dataframe
data = {}
for x in range(0, len(columns)):
    name = columns[x]
    value = values[x]
    data[name] = value

#Creating the dataFrame, setting an numeric index. 
dataFrame_costs = pd.DataFrame(data, columns= columns, index=[0])

dataFrame_costs
# Out:
#   Kjøpsavgift Salgsavgift Forvaltningsavgift Resultatbastert avgift(maks)  \
# 0           0           0               1.75                            0
#
#   Løpende kostnader
# 0              2.00

# %% [markdown]
# We got ourselves a dataframe with the available information regarding costs for this fund!
#
# You might not have flinched, but notice that we're setting the missing values to 0. This is because Nordnet uses '-' as a placeholder for when the cost is zero! If they were missing values, this assumption could lead to misinformation and faulty analytics.

# %% [markdown]
# The second piece of information we want from this page is the `standard deviation` and the `Sharpe Ratio`. Let's get that information and process it in the same way as for the costs.

# %%
volatility_table = overview_soup.find("a", text = "Gj.snitt avkastning").parent.parent.parent

row_names = ["Gj.snitt avkastning", "Standardavvik", "Sharpe Ratio"]
td_tags = volatility_table.findAll("td", class_=None)

#Regex to find the values in the td_tags, or insert '-' if no value
values = [re.findall("\d+\.\d+", text.text)[0] if re.findall("\d+\.\d+", text.text) else '0'  for text in td_tags]

columns = ["Gj.snitt avkastning", "Standardavvik", "Sharpe Ratio"]

# Creating the dictionary in which our data lies, which will be used to initiate the dataframe
data = {}
for x in range(0, len(columns)):
    name = columns[x]
    value = values[x]
    data[name] = value

#Creating the dataFrame, setting an numeric index. 
dataFrame_volatility = pd.DataFrame(data, columns= columns, index=[0])

dataFrame_volatility
# Out:
#   Gj.snitt avkastning Standardavvik Sharpe Ratio
# 0                5.21         12.78         0.36

# %% [markdown]
# There we go, another dataFrame containing the volatility information on the fund!
#
# The next step is to combine the two dataFrames, and put the name of the fund as a column

# %%
dataframe_fund = pd.concat([dataFrame_costs, dataFrame_volatility], axis=1)

fund_name = overview_soup.find("div", id="container").h1.text

dataframe_fund['Name'] = fund_name

dataframe_fund
# Out:
#   Kjøpsavgift Salgsavgift Forvaltningsavgift Resultatbastert avgift(maks)  \
# 0           0           0               1.75                            0
#
#   Løpende kostnader Gj.snitt avkastning Standardavvik Sharpe Ratio  \
# 0              2.00                5.21         12.78         0.36
#
#                                                 Name
# 0  Aberdeen Global - Asia Pacifc Equity Fund A Ac...

# %% [markdown]
# <h2> Checkpoint Bravo </h2>
#
# We now how a more or less complete dataframe for one fund! Later we'll add more data, but for now let's look at cleaning up our project by putting functionality in functions, in order to make our code cleaner!
#
# From here on we go to our next Jupyter Notebook file: `Creating the complete dataframe`
